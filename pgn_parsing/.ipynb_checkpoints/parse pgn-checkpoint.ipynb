# %%
from collections import defaultdict
import sys
import networkx as nx
import matplotlib as plt
import numpy as np
import re
import chess
import subprocess
import timeit
import pickle
import stockfish
from stockfish import Stockfish
import chess
import chess.engine

engine = chess.engine.SimpleEngine.popen_uci("../stockfish-10-64")
stockfish = Stockfish("../stockfish-10-64")

# %%
def varWeighted(scores, counts):
    if (len(counts)<2):
        return None
    else:
        weightedMean = sum([a*b for a,b in zip(scores,counts)])/sum(counts)
        scoreDiffs = [(score - weightedMean)**2 for score in scores]
        V1 = sum(counts)
        V2 = sum([count**2 for count in counts])
        var = (V1/(V1**2-V2)) * sum([a*b for a,b in zip(counts,scoreDiffs)])
        return var
    
def get_score(san):
    board = chess.Board()
    for move in san:
        try:
            board.push_san(move)
        except:
            break
    currFen = board.fen()
    score = engine.analyse(board, chess.engine.Limit(time=.05), info=chess.engine.INFO_SCORE)
    if('#' in str(score['score'])):
        if('-' in str(score['score'])):
            return -39765
        else:
            return 39765
    else:
        score = int(str(score["score"]))
    return score

def san_to_fen(san):
    board = chess.Board()
    for move in san:
        try:
            board.push_san(move)
        except:
            break
    currFen = board.fen()
    return currFen

def get_node_sd(node):
    scores = []
    counts = []
    try:
        for neighbor in list(g.neighbors(node)):
            scores.append(nx.get_node_attributes(g, 'score')[neighbor])
            counts.append(nx.get_node_attributes(g, 'movelistCount')[neighbor][node])
        return node, np.sqrt(varWeighted(scores,counts))
    except:
        return node, None

# %%
my_file = open("pgnparse.txt", "r")
pgn = my_file.read()

pgn_list = pgn.split("\n")
my_file.close()
print(len(pgn_list))

pgn_list = list(filter(None, pgn_list))
print(len(pgn_list))
# Out:
# 242666
# 121332

# %%
pgn_list[1]
# Out:
# '[Event "Rated Classical game"  [Site "https://lichess.org/a9tcp02g"  [White "Desmond_Wilson"  [Black "savinka59"  [Result "1-0"  [UTCDate "2012.12.31"  [UTCTime "23:04:12"  [WhiteElo "1654"  [BlackElo "1919"  [WhiteRatingDiff "+19"  [BlackRatingDiff "-22"  [ECO "D04"  [Opening "Queen\'s Pawn Game: Colle System, Anti-Colle"  [TimeControl "480+2"  [Termination "Normal"   [mainline 1. d4 d5 2. Nf3 Nf6 3. e3 Bf5 4. Nh4 Bg6 5. Nxg6 hxg6 6. Nd2 e6 7. Bd3 Bd6 8. e4 dxe4 9. Nxe4 Rxh2 10. Ke2 Rxh1 11. Qxh1 Nc6 12. Bg5 Ke7 13. Qh7 Nxd4+ 14. Kd2 Qe8 15. Qxg7 Qh8 16. Bxf6+ Kd7 17. Qxh8 Rxh8 18. Bxh8 1-0  '

# %%
start = timeit.default_timer()
d = defaultdict(list)
cnt = 0
for item in pgn_list:
    l = item.split('[mainline')
    try:
        info = l[0].split('"')
        #mainline = l[1]
        tuples = list(zip(info[::2],info[1::2]))
        tuples.append(('mainline', l[1]))

        for a, b in tuples:
            d[a].append(b)

        
    except:
         print('problem parsing:', item)
print("TIME:", timeit.default_timer()- start)
# Out:
# TIME: 0.9674050770000235

# %%
df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in d.items() ]))
print(df.shape)
df.head()
# Out:
# (121332, 18)
#                 [Event                         [Site            [White   \
# 0  Rated Classical game  https://lichess.org/j1dkb5dw             BFG9k
# 1  Rated Classical game  https://lichess.org/a9tcp02g    Desmond_Wilson
# 2  Rated Classical game  https://lichess.org/szom2tog     Kozakmamay007
# 3     Rated Bullet game  https://lichess.org/rklpc7mk  Naitero_Nagasaki
# 4     Rated Bullet game  https://lichess.org/1xb3os63      nichiren1967
#
#              [Black    [Result    [UTCDate    [UTCTime    [WhiteElo   \
# 0            mamalak        1-0  2012.12.31    23:01:03         1639
# 1          savinka59        1-0  2012.12.31    23:04:12         1654
# 2  VanillaShamanilla        1-0  2012.12.31    23:03:15         1643
# 3                800        0-1  2012.12.31    23:04:57         1824
# 4   Naitero_Nagasaki        0-1  2012.12.31    23:02:37         1765
#
#     [BlackElo    [WhiteRatingDiff    [BlackRatingDiff    [ECO   \
# 0         1403                  +5                  -8     C00
# 1         1919                 +19                 -22     D04
# 2         1747                 +13                 -94     C50
# 3         1973                  -6                  +8     B12
# 4         1815                  -9                  +9     C00
#
#                                      [Opening    [TimeControl   \
# 0             French Defense: Normal Variation           600+8
# 1  Queen's Pawn Game: Colle System, Anti-Colle           480+2
# 2         Four Knights Game: Italian Variation          420+17
# 3         Caro-Kann Defense: Goldman Variation            60+1
# 4     French Defense: La Bourdonnais Variation            60+1
#
#     [Termination                                            mainline  \
# 0          Normal   1. e4 e6 2. d4 b6 3. a3 Bb7 4. Nc3 Nh6 5. Bxh...
# 1          Normal   1. d4 d5 2. Nf3 Nf6 3. e3 Bf5 4. Nh4 Bg6 5. N...
# 2          Normal   1. e4 e5 2. Nf3 Nc6 3. Bc4 Nf6 4. Nc3 Bc5 5. ...
# 3          Normal   1. e4 c6 2. Nc3 d5 3. Qf3 dxe4 4. Nxe4 Nd7 5....
# 4          Normal   1. e4 e6 2. f4 d5 3. e5 c5 4. Nf3 Qb6 5. c3 N...
#
#     [BlackTitle    [WhiteTitle
# 0             LM             LM
# 1             LM             LM
# 2             LM             LM
# 3             LM             LM
# 4             LM             LM

# %%
df['san'] = df.mainline.apply(lambda x: [ i for i in x.split() if "." not in i ])

# %%
df['fen'] = df.san.apply(lambda x: san_to_fen(x))

# %%
df.head()
# Out:
#                 [Event                         [Site            [White   \
# 0  Rated Classical game  https://lichess.org/j1dkb5dw             BFG9k
# 1  Rated Classical game  https://lichess.org/a9tcp02g    Desmond_Wilson
# 2  Rated Classical game  https://lichess.org/szom2tog     Kozakmamay007
# 3     Rated Bullet game  https://lichess.org/rklpc7mk  Naitero_Nagasaki
# 4     Rated Bullet game  https://lichess.org/1xb3os63      nichiren1967
#
#              [Black    [Result    [UTCDate    [UTCTime    [WhiteElo   \
# 0            mamalak        1-0  2012.12.31    23:01:03         1639
# 1          savinka59        1-0  2012.12.31    23:04:12         1654
# 2  VanillaShamanilla        1-0  2012.12.31    23:03:15         1643
# 3                800        0-1  2012.12.31    23:04:57         1824
# 4   Naitero_Nagasaki        0-1  2012.12.31    23:02:37         1765
#
#     [BlackElo    [WhiteRatingDiff    [BlackRatingDiff    [ECO   \
# 0         1403                  +5                  -8     C00
# 1         1919                 +19                 -22     D04
# 2         1747                 +13                 -94     C50
# 3         1973                  -6                  +8     B12
# 4         1815                  -9                  +9     C00
#
#                                      [Opening    [TimeControl   \
# 0             French Defense: Normal Variation           600+8
# 1  Queen's Pawn Game: Colle System, Anti-Colle           480+2
# 2         Four Knights Game: Italian Variation          420+17
# 3         Caro-Kann Defense: Goldman Variation            60+1
# 4     French Defense: La Bourdonnais Variation            60+1
#
#     [Termination                                            mainline  \
# 0          Normal   1. e4 e6 2. d4 b6 3. a3 Bb7 4. Nc3 Nh6 5. Bxh...
# 1          Normal   1. d4 d5 2. Nf3 Nf6 3. e3 Bf5 4. Nh4 Bg6 5. N...
# 2          Normal   1. e4 e5 2. Nf3 Nc6 3. Bc4 Nf6 4. Nc3 Bc5 5. ...
# 3          Normal   1. e4 c6 2. Nc3 d5 3. Qf3 dxe4 4. Nxe4 Nd7 5....
# 4          Normal   1. e4 e6 2. f4 d5 3. e5 c5 4. Nf3 Qb6 5. c3 N...
#
#     [BlackTitle    [WhiteTitle   \
# 0             LM             LM
# 1             LM             LM
# 2             LM             LM
# 3             LM             LM
# 4             LM             LM
#
#                                                  san  \
# 0  [e4, e6, d4, b6, a3, Bb7, Nc3, Nh6, Bxh6, gxh6...
# 1  [d4, d5, Nf3, Nf6, e3, Bf5, Nh4, Bg6, Nxg6, hx...
# 2  [e4, e5, Nf3, Nc6, Bc4, Nf6, Nc3, Bc5, a3, Bxf...
# 3  [e4, c6, Nc3, d5, Qf3, dxe4, Nxe4, Nd7, Bc4, N...
# 4  [e4, e6, f4, d5, e5, c5, Nf3, Qb6, c3, Nc6, d3...
#
#                                                  fen
# 0  r2kQb1r/pbpp3p/1pn1p3/7B/3PP2q/P1N5/1PP2PPP/R3...
# 1  7B/pppk1p2/3bp1p1/8/3nN3/3B4/PPPK1PP1/R7 b - -...
# 2  r1b1k2r/ppN2ppp/4q3/4p3/2BnP1n1/P2P1N1P/1PP3P1...
# 3              8/p5p1/6P1/6bP/K1pk4/8/8/8 w - - 0 48
# 4  r4b1r/pp3kp1/1q6/2ppP2p/5P2/2PP3b/PP1N4/R1B2K2...

# %%
print(get_score(df['san'][0]))
san_to_fen(df['san'][0])
# Out:
# -39765
# 'r2kQb1r/pbpp3p/1pn1p3/7B/3PP2q/P1N5/1PP2PPP/R3K2R b KQ - 2 13'
